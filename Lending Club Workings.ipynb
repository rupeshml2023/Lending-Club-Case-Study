# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df1 = pd.read_csv(r'C:\Users\rupesh.kv\Lending club case study\Data file.csv')
df1.head()
# Out:
# C:\Users\rupesh.kv\AppData\Local\Temp\ipykernel_15112\2731701691.py:7: DtypeWarning: Columns (7,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r'C:\Users\rupesh.kv\Lending club case study\Data file.csv')
#         id  member_id loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5,000         5000           4975.0   36 months
# 1  1077430    1314167     2,500         2500           2500.0   60 months
# 2  1077175    1313524     2,400         2400           2400.0   36 months
# 3  1076863    1277178    10,000        10000          10000.0   36 months
# 4  1075358    1311748     3,000         3000           3000.0   60 months
#
#   int_rate installment grade sub_grade  ... recoveries  \
# 0   10.65%         163     B        B2  ...       0.00
# 1   15.27%          60     C        C4  ...     117.08
# 2   15.96%          84     C        C5  ...       0.00
# ...

# %%
sns.boxplot(df1.funded_amnt_inv)
plt.show()
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.hist(df1.funded_amnt_inv, bins = 50)
# Out:
# (array([ 408.,  819., 1354., 1182., 1684., 2006., 1555., 2585., 2449.,
#         1251., 1736., 1965., 1332., 1150., 2578.,  777.,  846., 2086.,
#          777.,  675.,  928., 1694.,  901.,  309.,  404.,  665.,  267.,
#          382., 1166.,  249.,  222.,  243.,  218.,  257.,  455.,  807.,
#           48.,   62.,   56.,  102.,   76.,   49.,  298.,   21.,   19.,
#           53.,   17.,   30.,   37.,  467.]),
#  array([    0.,   700.,  1400.,  2100.,  2800.,  3500.,  4200.,  4900.,
#          5600.,  6300.,  7000.,  7700.,  8400.,  9100.,  9800., 10500.,
#         11200., 11900., 12600., 13300., 14000., 14700., 15400., 16100.,
#         16800., 17500., 18200., 18900., 19600., 20300., 21000., 21700.,
#         22400., 23100., 23800., 24500., 25200., 25900., 26600., 27300.,
#         28000., 28700., 29400., 30100., 30800., 31500., 32200., 32900.,
#         33600., 34300., 35000.]),
#  <BarContainer object of 50 artists>)

# %%
df2=df1 [[ 'loan_status','grade','member_id']]

# %%
df3=pd.pivot_table(df2,values='member_id',index='grade',columns='loan_status',aggfunc='count')
df3
# Out:
# loan_status  Charged Off  Current  Fully Paid
# grade
# A                    602       40        9443
# B                   1425      345       10250
# C                   1347      264        6487
# D                   1118      222        3967
# E                    715      179        1948
# F                    319       73         657
# G                    101       17         198

# %%
#Grade wise Loan Status ( Denoting Grade B,C, and D have more Charge off % among there total loan Value)
df3.plot(kind='bar', stacked=True)

plt.title('Grade wise Loan Status')
# Out:
# Text(0.5, 1.0, 'Grade wise Loan Status')

# %%
sns.heatmap(df5, cmap = "Reds", annot=True)
plt.show()

# %%
df3=pd.pivot_table(df2,values='member_id',index='grade',columns='loan_status',aggfunc='count')

sns.heatmap(df3, cmap = "Reds", annot=True)
plt.show()

# %%
df4=df1 [[ 'loan_status','emp_length','member_id']]
df5=pd.pivot_table(df4,values='member_id',index='emp_length',columns='loan_status',aggfunc='count')
df5
# Out:
# loan_status  Charged Off  Current  Fully Paid
# emp_length
# 1 year               456       71        2713
# 10+ years           1331      391        7157
# 2 years              567       97        3724
# 3 years              555       83        3457
# 4 years              462       94        2880
# 5 years              458       88        2736
# 6 years              307       61        1861
# 7 years              263       62        1448
# 8 years              203       44        1232
# 9 years              158       32        1068
# < 1 year             639       75        3869

# %%
#Employee Length of Exp to Loan Status ( Denoting those with 10+ years of experience have higher share of charged of cases among themselves
)
df5.plot(kind='bar', stacked=True)

plt.title('Emp Length wise Loan Status')
# Out:
# Text(0.5, 1.0, 'Emp Length wise Loan Status')

# %%
#Emp length wise Loan Recoveries
plt.figure(figsize=[10,7])
sns.boxplot(df8['emp_length'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='emp_length', ylabel='recoveries'>

# %%
#Denotes people with higher empl exp have higher fund amount invested
plt.figure(figsize=[10,7])
sns.boxplot(df8['emp_length'],df8.funded_amnt_inv)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='emp_length', ylabel='funded_amnt_inv'>

# %%
#Denotes people with higher empl exp have higher fund amount invested but the interest income earned is same across all empl exp group
plt.figure(figsize=[10,7])
sns.boxplot(df8['emp_length'],df8.total_rec_int)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='emp_length', ylabel='total_rec_int'>

# %%
df4=df1 [[ 'loan_status','emp_length','member_id']]
df5=pd.pivot_table(df4,values='member_id',index='emp_length',columns='loan_status',aggfunc='count')
sns.heatmap(df5, cmap = "Reds", annot=True)
plt.show()

# %%
#Salary Range wise Loan Recoveries
plt.figure(figsize=[10,7])
sns.boxplot(df8['Sal Bucket'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sal Bucket', ylabel='recoveries'>

# %%
#State wise Recoveries vs home ownership ( Denotes certain states where customers with home mortgage denote large recoveries, indicating a risk premium to be attributed from theses state customers. Also it denotes customer with no mortgage have less recovery compared to the customers with Mortgage)
df6=df1 [[ 'addr_state','home_ownership','recoveries']]
df7=pd.pivot_table(df6,values='recoveries',index='addr_state',columns='home_ownership',aggfunc='sum')
sns.heatmap(df7, cmap = "Reds", annot=False)
plt.show()

# %%
plt.figure(figsize=[10,7])
sns.boxplot(df8['addr_state'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='addr_state', ylabel='recoveries'>

# %%
# Home ownership to loans ending in recoveries ( Denotes people with Mortage tend to have higher chances of ending into recoveries)
plt.figure(figsize=[10,7])
sns.boxplot(df8['home_ownership'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='home_ownership', ylabel='recoveries'>

# %%
plt.figure(figsize=[10,7])
sns.boxplot(df8['sub_grade'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sub_grade', ylabel='recoveries'>

# %%
#Denotes the verified cases have higher chances by value in ending up with loan recoveris may be the "verififcation" needs further scrutiny
plt.figure(figsize=[10,7])
sns.boxplot(df8['verification_status'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='verification_status', ylabel='recoveries'>

# %%
#Type of loan vs Home ownership and the corresponding interest earned( Denotes customers availaing Credit card,home improvement,small business have higher pottential to earn intrest income)
T2=df1[[ 'purpose','total_rec_int','home_ownership']]
T3=pd.pivot_table(T2,values='total_rec_int',index='purpose',columns='home_ownership',aggfunc='sum')
sns.heatmap(T3, cmap = "Greens", annot=False)
plt.show()

# %%
plt.figure(figsize=[20,7])
sns.boxplot(df8['purpose'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='purpose', ylabel='recoveries'>

# %%
#Annual income vs funded amnt investedvs recoveries,total interest recieved ( Denotes lower the annual income higer is the value of recoveries,the Funded amount invested is higher ins applicants with less than 10K in salary,Highest recoevries are in the bracket of applicants under 5K in salary, More than 50% of interest recieved is from applicants with salary under 10K)
sns.pairplot(df1[['annual_inc','funded_amnt_inv','recoveries','total_rec_int']])
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df8 = pd.read_csv(r'C:\Users\rupesh.kv\Lending club case study\Data_file_R.csv',encoding= 'unicode_escape')

df9=pd.pivot_table(df8,values='id',index='Sal Bucket',columns='loan_status',aggfunc='count')
df9.head()
# Out:
# C:\Users\rupesh.kv\AppData\Local\Temp\ipykernel_15112\865319264.py:4: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8 = pd.read_csv(r'C:\Users\rupesh.kv\Lending club case study\Data_file_R.csv',encoding= 'unicode_escape')
# loan_status  Charged Off  Current  Fully Paid
# Sal Bucket
# 100K-200K            532      190        4379
# 10K-20K              217        8         865
# 200K-500K             49       15         450
# 20K-30K              602       64        2769
# 30K-40K              912      106        4235

# %%
#Salary Range wise Loan stauts -( Denoting applicants under the 20K-60K have higher rate of Charge of cases againts the total population)
sns.heatmap(df9, cmap = "Reds", annot=False)
plt.show()

# %%
#Grade of Loan vs Interset rate range (denotes the apllpicants availaing interest rate of 5%-10% is less than 33%)
df10=pd.pivot_table(df8,values='funded_amnt_inv',index='grade',columns='Rate Bucket',aggfunc='sum')
df10.plot(kind='bar', stacked=True)
plt.title('Grade vs Interest Rate range')
# Out:
# Text(0.5, 1.0, 'Grade vs Interest Rate range')

# %%
# Grade vs Recoveries ( Denotes loan categorized B to D having interest rate higher than 10% has higher charge off cases, applicants availing Car,house,medical have lower chance of recoveries)
df11=pd.pivot_table(df8,values='recoveries',index='purpose',columns='grade',aggfunc='count')
sns.heatmap(df11, cmap = "Reds", annot=False)
plt.show()

# %%
# Denotes state wise Loan grade ( Denotes most states have Grabde B and Above loans which are at 10% and above . Except for states like CA, FL and NY)
df12=pd.pivot_table(df8,values='recoveries',index='addr_state',columns='grade',aggfunc='sum')
df12.plot(kind= 'bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='addr_state'>

# %%
plt.hist(df8.sub_grade, bins=75)
plt.show()

# %%
df8['recoveries'] = pd.to_numeric(df8['recoveries'], errors='coerce')

# %%
# Loan type recoveries denoting loan type E and D have 2 times higher average of loan turning upto recoveries
sns.boxplot(df8['grade'],df8.recoveries)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='grade', ylabel='recoveries'>

# %%
df8['total_pymnt'] = pd.to_numeric(df8['total_pymnt'], errors='coerce')
df8['total_rec_prncp'] = pd.to_numeric(df8['total_rec_prncp'], errors='coerce')
df8['total_rec_int'] = pd.to_numeric(df8['total_rec_int'], errors='coerce')

# %%
# Loan type recoveries denoting loan type E and D have 2 times higher average of loan turning upto recoveries
sns.boxplot(df8['grade'],df8.total_pymnt)
# Out:
# C:\Users\rupesh.kv\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='grade', ylabel='total_pymnt'>
